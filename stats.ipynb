# %%
import json

data = []
for i, line in enumerate(open('meetups.json')):
	line = line.strip()
	if line.startswith('[{'):
		line = line[1:]
	if line.endswith('},'):
		line = line[:-1]
	if i % 10000 == 0:
		print('..',i)
	try:
		data.append(json.loads(line))
	except:
		print('fail at',i)
# Out:
# .. 0
# .. 1000
# .. 2000
# .. 3000
# .. 4000
# .. 5000
# .. 6000
# .. 7000
# .. 8000
# .. 9000
# .. 10000
# .. 11000
# .. 12000
# .. 13000
# .. 14000
# .. 15000
# .. 16000
# .. 17000
# .. 18000
# .. 19000
# .. 20000
# .. 21000
# .. 22000
# .. 23000
# .. 24000
# .. 25000
# .. 26000
# .. 27000
# .. 28000
# .. 29000
# .. 30000
# .. 31000
# .. 32000
# .. 33000
# .. 34000
# .. 35000
# .. 36000
# .. 37000
# .. 38000
# .. 39000
# .. 40000
# .. 41000
# .. 42000
# .. 43000
# .. 44000
# .. 45000
# .. 46000
# .. 47000
# .. 48000
# .. 49000
# .. 50000
# .. 51000
# .. 52000
# .. 53000
# .. 54000
# .. 55000
# .. 56000
# .. 57000
# .. 58000
# .. 59000
# .. 60000
# .. 61000
# .. 62000
# .. 63000
# .. 64000
# .. 65000
# .. 66000
# .. 67000
# .. 68000
# .. 69000
# .. 70000
# .. 71000
# .. 72000
# .. 73000
# .. 74000
# .. 75000
# .. 76000
# .. 77000
# .. 78000
# .. 79000
# .. 80000
# .. 81000
# .. 82000
# .. 83000
# .. 84000
# .. 85000
# .. 86000
# .. 87000
# .. 88000
# .. 89000
# .. 90000
# .. 91000
# .. 92000
# .. 93000
# .. 94000
# .. 95000
# .. 96000
# .. 97000
# .. 98000
# .. 99000
# .. 100000
# .. 101000
# .. 102000
# .. 103000
# .. 104000
# .. 105000
# .. 106000
# .. 107000
# .. 108000
# .. 109000
# .. 110000
# .. 111000
# .. 112000
# .. 113000
# .. 114000
# .. 115000
# .. 116000
# .. 117000
# .. 118000
# .. 119000
# .. 120000
# .. 121000
# .. 122000
# .. 123000
# .. 124000
# .. 125000
# .. 126000
# .. 127000
# .. 128000
# .. 129000
# .. 130000
# .. 131000
# .. 132000
# .. 133000
# .. 134000
# .. 135000
# .. 136000
# .. 137000
# .. 138000
# .. 139000
# .. 140000
# .. 141000
# .. 142000
# .. 143000
# .. 144000
# .. 145000
# .. 146000
# .. 147000
# .. 148000
# .. 149000
# .. 150000
# .. 151000
# .. 152000
# .. 153000
# .. 154000
# .. 155000
# .. 156000
# .. 157000
# .. 158000
# .. 159000
# .. 160000
# .. 161000
# .. 162000
# .. 163000
# .. 164000
# .. 165000
# .. 166000
# .. 167000
# .. 168000
# .. 169000
# .. 170000
# .. 171000
# .. 172000
# .. 173000
# .. 174000
# .. 175000
# .. 176000
# .. 177000
# .. 178000
# .. 179000
# .. 180000
# .. 181000
# .. 182000
# .. 183000
# .. 184000
# .. 185000
# .. 186000
# .. 187000
# .. 188000
# .. 189000
# .. 190000
# .. 191000
# .. 192000
# .. 193000
# .. 194000
# .. 195000
# .. 196000
# .. 197000
# .. 198000
# .. 199000
# .. 200000
# .. 201000
# .. 202000
# .. 203000
# .. 204000
# .. 205000
# .. 206000
# .. 207000
# .. 208000
# .. 209000
# .. 210000
# .. 211000
# .. 212000
# .. 213000
# .. 214000
# .. 215000
# .. 216000
# .. 217000
# .. 218000
# .. 219000
# .. 220000
# .. 221000
# .. 222000
# .. 223000
# .. 224000
# .. 225000
# .. 226000
# .. 227000
# .. 228000
# .. 229000
# .. 230000
# .. 231000
# .. 232000
# .. 233000
# .. 234000
# .. 235000
# .. 236000
# .. 237000
# .. 238000
# .. 239000
# .. 240000
# .. 241000
# .. 242000
# .. 243000
# .. 244000
# .. 245000
# fail at 245017

# %%
groups = [x for x in data if x['type'] == 'group']
print('groups',len(groups))
events = [x for x in data if x['type'] == 'event']
print('events',len(events))
members = [x for x in data if x['type'] == 'member']
print('members',len(members))
# Out:
# groups 88028
# events 51904
# members 105085

# %%
events[231]
# Out:
# {'attendees': ['http://www.meetup.com/Boston-Walking/members/13274498',
#   'http://www.meetup.com/Boston-Walking/members/71490452'],
#  'description': '<div id="event-description-wrap" itemprop="description" class="line redactor-description">\n<p><b>From Here to There and Beyond or</b></p> \n<p><b>How I gave up Molecular Biology to become a City Councillor and</b></p> \n<p><b>What happened next!</b></p> \n<p><img src="http://photos4.meetupstatic.com/photos/event/9/7/d/5/600_442538869.jpeg" style="margin : 5px ; max-width : 700px ; max-height : 700px"></p> \n<p> Minka Van Beuzekom was a member of the Cambridge City Council [masked]) and is running again this year. She has a BS in Molecular Biology from Wellesley College and a BA in Public Health from Boston University, focusing on Epidemiology, Biostatistics, and Environmental Health. While on the City Council she served on at least twelve committees and has been involved in a wide range of community services from establishing Little Free Libraries to rodent control. She is also a member of the Cambridge Club, which although thriving and distinguished, is not as old as the Economy Club. She will speak about how she became interested in running for public office and what it is like to serve as a City Councillor. About the Dinner: Usually about 20 to 35 people composed of members and meetup invitees.</p> \n<p><img src="http://photos1.meetupstatic.com/photos/event/9/7/e/1/600_442538881.jpeg" style="margin : 5px ; max-width : 700px ; max-height : 700px"></p> \n<p>Social Hour: 6:00 p.m. Dinner: 7:00 p.m. Speaker : Around 8 p.m. You can come at any time.</p>\n</div>',
#  'location': {'country-name': 'us',
#   'latitude': 42.34,
#   'locality': 'Brookline',
#   'longitude': -71.12,
#   'placename': 'Cambridge,MA, us',
#   'postal-code': '02446',
#   'region': 'MA'},
#  'start_time': '2015-10-05T18:00:00-04:00',
#  'title': 'Dinner and lecture: How (and why?) I became a City Councillor!',
#  'type': 'event',
#  'url': 'http://www.meetup.com/Boston-Walking/events/225705363/'}

# %%
from collections import Counter

def stats(arr,key,keygetter=lambda el, key:el[key],limit=10):
    def flat(arr):
        for x in arr:
            if type(x) == type([]):
                yield from flat(x)
            else:
                x = str(x)
                yield x.strip()

    c = Counter(flat([keygetter(el,key) for el in arr]))

    count_all = len(arr)
    count_distinct = len(c)
    print()
    print(key,"   -   ",count_all,"values,",count_distinct,"distincts")
    print('----')

    for el,n in c.most_common(limit):
        p = n/count_all*100
        print("{:.1f}% ({}) {}".format(p,n,el))
    print()

stats(events,"country-name",lambda el,key:el["location"][key], limit=10)
stats(events,"placename",lambda el,key:el["location"][key])
stats(events,"region",lambda el,key:el["location"][key])
stats(events,"title")
# Out:
# country-name    -    51904 values, 86 distincts
# ----
# 68.8% (35697) us
# 7.9% (4083) gb
# 5.7% (2979) ca
# 3.6% (1887) au
# 1.3% (670) in
# 1.1% (567) de
# 0.9% (465) es
# 0.9% (452) nz
# 0.8% (418) it
# 0.8% (408) nl
#
#
# placename    -    51904 values, 11119 distincts
# ----
# 1.9% (982) London,, gb
# 1.3% (694) New York,NY, us
# 0.8% (424) Austin,TX, us
# 0.8% (412) Toronto,ON, ca
# 0.7% (346) Los Angeles,CA, us
# 0.7% (345) Chicago,IL, us
# 0.6% (333) San Diego,CA, us
# 0.6% (322) Seattle,WA, us
# 0.6% (304) San Francisco,CA, us
# 0.6% (302) Calgary,AB, ca
#
#
# region    -    51904 values, 264 distincts
# ----
# 14.2% (7395) CA
# 5.2% (2723) TX
# 5.2% (2688) NY
# 4.5% (2344) FL
# 3.6% (1874) AU
# 3.1% (1607) CO
# 3.0% (1542) 17
# 2.9% (1482) ON
# 2.6% (1358) WA
# 2.6% (1339) IL
#
#
# title    -    51904 values, 47477 distincts
# ----
# 0.1% (45) Monthly Meeting
# 0.1% (36) TBD
# 0.0% (24) Reiki Share
# 0.0% (22) Monthly Meetup
# 0.0% (22) Toastmasters Meeting
# 0.0% (22) Let's discuss what we want out of the Group.
# 0.0% (21) Club Meeting
# 0.0% (20) Zumba
# 0.0% (19) Meeting
# 0.0% (19) Meet and Greet
